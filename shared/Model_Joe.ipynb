# %%
import nltk
import pandas as pd
import re
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import matplotlib.colors as mcolors

# %% [markdown]
# nltk downloads should be put here!

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Load Data

# %%
import pandas as pd
df = pd.read_csv('processed_final_Joe.csv')

# %%
df.head()
# Out:
#                 id_str           created_at  \
# 0  1200141368619868161  2019-11-28 19:56:14
# 1  1199910665680543745  2019-11-28 04:39:30
# 2  1200449458741424130  2019-11-29 16:20:28
# 3  1200542469407903744  2019-11-29 22:30:04
# 4  1200542451976589312  2019-11-29 22:30:00
#
#                                            full_text
# 0  It is Thanksgiving, @JoeBiden and @BarackObama...
# 1  Such BullS**t! ⁦@RudyGiuliani⁩ was President ⁦...
# 2  Wow, the fliers for @JoeBiden is upcoming Iowa...
# 3  @Alyssa_Milano \n\nSo in your world, better th...
# 4  @JoeBiden @QuancyClayborne Joe, if this is rea...

# %%
df.shape
# Out:
# (19090, 3)

# %% [markdown]
# # Data-specific Preprocessing

# %%
stop_words = nltk.corpus.stopwords.words('english')

# %%
stop_words.extend(['from', 'subject', 're', 'use',"get",'like','want','way','must','yet','take','look','still','hey', 'lol', 'day', 'liz',
                  'thanks', 'part', 'plan', 'lol', 'since', 'ever', 'yes', 'word', 'please', 'think', 'thing', 'need', 'joke',
                  'let', 'things', 'tell', 'yeah',
                   'nothing', 'everyone', 'anyone'
                   
                  ])

# %%
# tokenize the tweets

from string import punctuation

def tokenize(text):
    '''names = ["berniesanders", "bernie", "sanders", "bern",
             "elizabethwarren","elizabeth","warren", 'ewarren'
             "joebiden","joe","biden",
             'donaldtrump', 'donald', 'trump',
             'aoc', 'cortez'
            ]'''
    lowered = nltk.tokenize.word_tokenize(text.lower())
    stripped = [i.strip().strip(punctuation) for i in lowered]
    tokenized = [t for t in lowered if t not in stop_words if len(t)>2] #if t not in names
    return tokenized

# %% [markdown]
# # Tokenization

# %%
data = df['full_text']

tokenized_data = []
for text in data:
    tokenized_data.append(tokenize(text))

# %% [markdown]
# # PoS Tagging

# %%
tagged_data = [nltk.pos_tag(t) for t in tokenized_data]

# %%
tagged_data[:5]
# Out:
# [[('thanksgiving', 'VBG'),
#   ('joebiden', 'JJ'),
#   ('barackobama', 'NN'),
#   ('nantucket', 'NN'),
#   ('realdonaldtrump', 'NN'),
#   ('war', 'NN'),
#   ('zone', 'NN'),
#   ('flotus', 'NN'),
#   ('troops', 'VBZ'),
#   ('god', 'JJ'),
#   ('bless', 'NN'),
#   ('first', 'RB'),
#   ('family', 'NN')],
#  [('bulls**t', 'NN'),
#   ('rudygiuliani\u2069', 'NN'),
#   ('president', 'NN'),
#   ('realdonaldtrump', 'VB'),
#   ('attorney', 'NN'),
#   ('obligated', 'VBN'),
#   ('investigate', 'NN'),
#   ('took', 'VBD'),
#   ('including\u2069', 'JJ'),
#   ('ukraine', 'JJ'),
#   ('msm', 'NN'),
#   ('pissed', 'VBD'),
#   ('found', 'VBN'),
#   ('joebiden\u2069', 'NN'),
#   ('briberyandextortion', 'NN')],
#  [('wow', 'NN'),
#   ('fliers', 'NNS'),
#   ('joebiden', 'VBP'),
#   ('upcoming', 'VBG'),
#   ('iowa', 'NN'),
#   ('bus', 'NN'),
#   ('tour', 'NN'),
#   ('surprisingly', 'RB'),
#   ('honest', 'JJS')],
#  [('alyssa_milano', 'NN'),
#   ('world', 'NN'),
#   ('better', 'RBR'),
#   ('woman', 'NN'),
#   ('dead', 'JJ'),
#   ('able', 'JJ'),
#   ('protect', 'NN'),
#   ('joebiden', 'NN'),
#   ('putting', 'VBG'),
#   ('hands', 'NNS'),
#   ('breasts', 'NNS'),
#   ('young', 'JJ'),
#   ('girls', 'NNS'),
#   ('molestation', 'NN'),
#   ('misunderstood', 'NN')],
#  [('joebiden', 'JJ'),
#   ('quancyclayborne', 'NN'),
#   ('joe', 'NN'),
#   ('really', 'RB'),
#   ('true', 'JJ'),
#   ('really', 'RB'),
#   ('quit', 'VB'),
#   ('clinging', 'VBG'),
#   ('tired', 'JJ'),
#   ('outdated', 'JJ'),
#   ('view', 'NN'),
#   ('legalizing', 'VBG'),
#   ('pot', 'NN'),
#   ('holdover', 'NN'),
#   ('preserving', 'VBG'),
#   ('prohibition', 'NN'),
#   ('era', 'NN'),
#   ('enforcement', 'NN'),
#   ('empire', 'NN'),
#   ('1930', 'CD'),
#   ('costs', 'VBZ'),
#   ('taxpayers', 'NNS'),
#   ('operate', 'VBP'),
#   ('wrong', 'JJ'),
#   ('wrong', 'JJ')]]

# %% [markdown]
# # Lemmatization/Stemming

# %%
#from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet

def get_wordnet_pos(word, tag):
    """Map POS tag to first character lemmatize() accepts"""
    tag = tag[0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

#temmer = PorterStemmer()
#def get_stemmed_tokens(tokens):
#    token = []
#    for token_list in tokens:
#        texts = [p_stemmer.stem(i) for i in token_list if ]
#        token.append(texts)
#    return token

lemmatizer = WordNetLemmatizer()

tagnames = ['NN','NNS', 'NNP', 'NNPS'] # 'JJ', 'VB', 'VBG', 'VBN', 'VBP', 'VBZ
lemmatized_data = []

for tagged_doc in tagged_data:
    temp = []
    for t1, t2 in tagged_doc:
        if t2 in tagnames:
            temp.append(lemmatizer.lemmatize(t1, get_wordnet_pos(word=t1, tag=t2)))
    lemmatized_data.append(temp)

lemmatized_data[:5]
# Out:
# [['barackobama',
#   'nantucket',
#   'realdonaldtrump',
#   'war',
#   'zone',
#   'flotus',
#   'bless',
#   'family'],
#  ['bulls**t',
#   'rudygiuliani\u2069',
#   'president',
#   'attorney',
#   'investigate',
#   'msm',
#   'joebiden\u2069',
#   'briberyandextortion'],
#  ['wow', 'flier', 'iowa', 'bus', 'tour'],
#  ['alyssa_milano',
#   'world',
#   'woman',
#   'protect',
#   'joebiden',
#   'hand',
#   'breast',
#   'girl',
#   'molestation',
#   'misunderstood'],
#  ['quancyclayborne',
#   'joe',
#   'view',
#   'pot',
#   'holdover',
#   'prohibition',
#   'era',
#   'enforcement',
#   'empire',
#   'taxpayer']]

# %% [markdown]
# # Corpus Generation / Indexing

# %%
import gensim
from gensim import corpora


dictionary = corpora.Dictionary(lemmatized_data)
print(len(dictionary))

# filter for terms which occur in no less than 0.1% of the documents (here tweets) and no more than 0.9% of the documents (tweets)
dictionary.filter_extremes(no_below=20, no_above=0.5)

print(len(dictionary))
# Out:
# 13243
# 714

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in lemmatized_data]

# %% [markdown]
# # LDA-Topic Model

# %%
topics_to_discover = 4

# %%
# Creating the object for LDA model using gensim library
lda_object = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
model_lda = lda_object(doc_term_matrix, num_topics=topics_to_discover, id2word = dictionary,
                                passes=50, minimum_probability = 0.8,
                                random_state = 42)

# %%
model_lda.print_topics(num_topics=topics_to_discover, num_words=5)
# Out:
# [(0,
#   '0.063*"trump" + 0.030*"time" + 0.029*"country" + 0.026*"man" + 0.024*"president"'),
#  (1,
#   '0.056*"joe" + 0.046*"people" + 0.042*"year" + 0.028*"potus" + 0.022*"president"'),
#  (2,
#   '0.119*"realcandaceo" + 0.083*"joe" + 0.060*"biden" + 0.052*"hunter" + 0.043*"trump"'),
#  (3,
#   '0.069*"realdonaldtrump" + 0.040*"kid" + 0.027*"nra" + 0.023*"democrat" + 0.020*"party"')]

# %% [markdown]
# # Visualizations

# %%
import pyLDAvis
import pyLDAvis.gensim
vis = pyLDAvis.gensim.prepare(topic_model=model_lda, corpus=doc_term_matrix, dictionary=dictionary)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el381140462647884240827159739"></div>
# <script type="text/javascript">
#
# var ldavis_el381140462647884240827159739_data = {"mdsDat": {"x": [0.14622461248899427, 0.15877008962391626, 0.09095935597901551, -0.39595405809192596], "y": [0.32850485467752344, -0.18624683708036396, -0.15360576493249975, 0.011347747335340162], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [28.910673141479492, 25.654399871826172, 23.92649269104004, 21.508434295654297]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [2075.0, 2255.0, 892.0, 1037.0, 908.0, 1731.0, 512.0, 951.0, 597.0, 917.0, 402.0, 408.0, 349.0, 426.0, 678.0, 603.0, 369.0, 293.0, 302.0, 260.0, 472.0, 280.0, 249.0, 248.0, 1352.0, 232.0, 243.0, 240.0, 240.0, 209.0, 2075.07763671875, 1037.12744140625, 907.6775512695312, 596.6937255859375, 425.57275390625, 368.484619140625, 176.42971801757812, 155.887939453125, 140.7566375732422, 141.74571228027344, 133.3728790283203, 135.0175018310547, 127.91813659667969, 123.99871063232422, 122.130126953125, 118.65797424316406, 108.97772979736328, 110.1118392944336, 108.35820007324219, 99.73336029052734, 98.67970275878906, 103.85637664794922, 95.44398498535156, 95.13072967529297, 82.20741271972656, 77.52232360839844, 77.05011749267578, 72.20255279541016, 71.16696166992188, 68.18966674804688, 69.73795318603516, 1444.4395751953125, 202.30194091796875, 675.692626953125, 308.9228515625, 752.4096069335938, 233.82215881347656, 175.0576934814453, 134.85983276367188, 126.66484069824219, 100.59378051757812, 407.99267578125, 301.5142517089844, 279.3291015625, 242.96725463867188, 239.38429260253906, 239.8520965576172, 223.2615966796875, 224.1462860107422, 198.38111877441406, 164.68751525878906, 161.98500061035156, 159.40184020996094, 156.83685302734375, 152.30059814453125, 145.9735870361328, 142.2391357421875, 139.43008422851562, 138.47161865234375, 135.62371826171875, 129.91299438476562, 125.20214080810547, 125.59912109375, 122.67698669433594, 110.8335952758789, 109.35480499267578, 107.02264404296875, 104.64997100830078, 102.27874755859375, 101.54747772216797, 102.06536102294922, 444.6318664550781, 978.7149658203125, 458.21649169921875, 216.6691436767578, 305.6274108886719, 366.3227844238281, 293.569091796875, 179.71861 ...

# %%
topics = model_lda.show_topics(formatted=False)
    
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[0],
                  prefer_horizontal=1.0)

for topic_num in range(topics_to_discover):
    fig, axes = plt.subplots(1, 1, figsize=(8,8), sharex=True, sharey=True)

    topic_words = dict(topics[topic_num][1])
    cloud.generate_from_frequencies(topic_words)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Wordcloud for Topic-{}'.format(topic_num+1), fontdict=dict(size=16))
    plt.gca().axis('off')


    plt.subplots_adjust(wspace=0, hspace=0)
    plt.axis('off')
    plt.margins(x=0, y=0)
    plt.tight_layout()
    plt.show()
